# %%
import pandas as pd
df = pd.read_csv("dinkes-od_17448_jml_penderita_diabetes_melitus_brdsrkn_kabupatenko_v2_data.csv")
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 0       KABUPATEN BOGOR                57769  ORANG   2019
# 1    KABUPATEN SUKABUMI               148447  ORANG   2019
# 2     KABUPATEN CIANJUR                12100  ORANG   2019
# ...

# %%
print(df.tail(5))
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 157  158             32    JAWA BARAT                 3275
# 158  159             32    JAWA BARAT                 3276
# 159  160             32    JAWA BARAT                 3277
# 160  161             32    JAWA BARAT                 3278
# 161  162             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 157         KOTA BEKASI                46481  ORANG   2024
# 158          KOTA DEPOK                44061  ORANG   2024
# 159         KOTA CIMAHI                10021  ORANG   2024
# 160    KOTA TASIKMALAYA                11782  ORANG   2024
# 161         KOTA BANJAR                 2415  ORANG   2024

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   162 non-null    int64
#  1   kode_provinsi        162 non-null    int64
#  2   nama_provinsi        162 non-null    object
#  3   kode_kabupaten_kota  162 non-null    int64
#  4   nama_kabupaten_kota  162 non-null    object
#  5   jumlah_penderita_dm  162 non-null    int64
#  6   satuan               162 non-null    object
#  7   tahun                162 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 10.3+ KB

# %%
df.describe()
# Out:
#                id  kode_provinsi  kode_kabupaten_kota  jumlah_penderita_dm  \
# count  162.000000          162.0           162.000000           162.000000
# mean    81.500000           32.0          3231.333333         29699.388889
# std     46.909487            0.0            31.298602         31787.221502
# min      1.000000           32.0          3201.000000             0.000000
# 25%     41.250000           32.0          3207.000000         12306.000000
# 50%     81.500000           32.0          3214.000000         19279.000000
# 75%    121.750000           32.0          3273.000000         39988.750000
# max    162.000000           32.0          3279.000000        242169.000000
#
#              tahun
# count   162.000000
# mean   2021.500000
# std       1.713121
# min    2019.000000
# 25%    2020.000000
# 50%    2021.500000
# 75%    2023.000000
# max    2024.000000

# %%
print(df['tahun'].unique())
# Out:
# [2019 2020 2021 2022 2023 2024]

# %%
print(df["nama_kabupaten_kota"].unique())
print(df["nama_kabupaten_kota"].nunique())
# Out:
# ['KABUPATEN BOGOR' 'KABUPATEN SUKABUMI' 'KABUPATEN CIANJUR'
#  'KABUPATEN BANDUNG' 'KABUPATEN GARUT' 'KABUPATEN TASIKMALAYA'
#  'KABUPATEN CIAMIS' 'KABUPATEN KUNINGAN' 'KABUPATEN CIREBON'
#  'KABUPATEN MAJALENGKA' 'KABUPATEN SUMEDANG' 'KABUPATEN INDRAMAYU'
#  'KABUPATEN SUBANG' 'KABUPATEN PURWAKARTA' 'KABUPATEN KARAWANG'
#  'KABUPATEN BEKASI' 'KABUPATEN BANDUNG BARAT' 'KABUPATEN PANGANDARAN'
#  'KOTA BOGOR' 'KOTA SUKABUMI' 'KOTA BANDUNG' 'KOTA CIREBON' 'KOTA BEKASI'
#  'KOTA DEPOK' 'KOTA CIMAHI' 'KOTA TASIKMALAYA' 'KOTA BANJAR']
# 27

# %%
print(df[["nama_kabupaten_kota", "jumlah_penderita_dm", "tahun"]])
# Out:
#     nama_kabupaten_kota  jumlah_penderita_dm  tahun
# 0       KABUPATEN BOGOR                57769   2019
# 1    KABUPATEN SUKABUMI               148447   2019
# 2     KABUPATEN CIANJUR                12100   2019
# 3     KABUPATEN BANDUNG                45412   2019
# 4       KABUPATEN GARUT                    0   2019
# ..                  ...                  ...    ...
# 157         KOTA BEKASI                46481   2024
# 158          KOTA DEPOK                44061   2024
# 159         KOTA CIMAHI                10021   2024
# 160    KOTA TASIKMALAYA                11782   2024
# 161         KOTA BANJAR                 2415   2024
#
# [162 rows x 3 columns]

# %%
df_2019 = df[df["tahun"] == 2019]
df_2019
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                 3201
# 1    2             32    JAWA BARAT                 3202
# 2    3             32    JAWA BARAT                 3203
# 3    4             32    JAWA BARAT                 3204
# 4    5             32    JAWA BARAT                 3205
# 5    6             32    JAWA BARAT                 3206
# 6    7             32    JAWA BARAT                 3207
# 7    8             32    JAWA BARAT                 3208
# 8    9             32    JAWA BARAT                 3209
# 9   10             32    JAWA BARAT                 3210
# 10  11             32    JAWA BARAT                 3211
# 11  12             32    JAWA BARAT                 3212
# 12  13             32    JAWA BARAT                 3213
# 13  14             32    JAWA BARAT                 3214
# 14  15             32    JAWA BARAT                 3215
# ...

# %%
df[df["jumlah_penderita_dm"] > 100000]
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 1    2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 14  15             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 41  42             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 42  43             32    JAWA BARAT                 3216    KABUPATEN BEKASI
# 68  69             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
#
#     jumlah_penderita_dm satuan  tahun
# 1                148447  ORANG   2019
# 14               149537  ORANG   2019
# 41               139392  ORANG   2020
# 42               242169  ORANG   2020
# 68               153547  ORANG   2021

# %%
df.sort_values(by="jumlah_penderita_dm", ascending=False)
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 42  43             32    JAWA BARAT                 3216
# 68  69             32    JAWA BARAT                 3215
# 14  15             32    JAWA BARAT                 3215
# 1    2             32    JAWA BARAT                 3202
# 41  42             32    JAWA BARAT                 3215
# ..  ..            ...           ...                  ...
# 19  20             32    JAWA BARAT                 3272
# 4    5             32    JAWA BARAT                 3205
# 10  11             32    JAWA BARAT                 3211
# 16  17             32    JAWA BARAT                 3217
# 17  18             32    JAWA BARAT                 3218
#
#         nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 42         KABUPATEN BEKASI               242169  ORANG   2020
# 68       KABUPATEN KARAWANG               153547  ORANG   2021
# 14       KABUPATEN KARAWANG               149537  ORANG   2019
# ...

# %%
df.sort_values(
    by=["tahun", "jumlah_penderita_dm"],
    ascending=[True, False]
)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 14    15             32    JAWA BARAT                 3215
# 1      2             32    JAWA BARAT                 3202
# 15    16             32    JAWA BARAT                 3216
# 6      7             32    JAWA BARAT                 3207
# 0      1             32    JAWA BARAT                 3201
# ..   ...            ...           ...                  ...
# 159  160             32    JAWA BARAT                 3277
# 156  157             32    JAWA BARAT                 3274
# 152  153             32    JAWA BARAT                 3218
# 154  155             32    JAWA BARAT                 3272
# 161  162             32    JAWA BARAT                 3279
#
#        nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 14      KABUPATEN KARAWANG               149537  ORANG   2019
# 1       KABUPATEN SUKABUMI               148447  ORANG   2019
# 15        KABUPATEN BEKASI                89055  ORANG   2019
# ...

# %%
df[df["tahun"] == 2019] \
  .sort_values(by="jumlah_penderita_dm", ascending=False) \
  .head(10)
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 14  15             32    JAWA BARAT                 3215  KABUPATEN KARAWANG
# 1    2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 15  16             32    JAWA BARAT                 3216    KABUPATEN BEKASI
# 6    7             32    JAWA BARAT                 3207    KABUPATEN CIAMIS
# 0    1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 23  24             32    JAWA BARAT                 3276          KOTA DEPOK
# 20  21             32    JAWA BARAT                 3273        KOTA BANDUNG
# 3    4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 22  23             32    JAWA BARAT                 3275         KOTA BEKASI
# 7    8             32    JAWA BARAT                 3208  KABUPATEN KUNINGAN
#
#     jumlah_penderita_dm satuan  tahun
# 14               149537  ORANG   2019
# 1                148447  ORANG   2019
# ...

# %%
df[df["nama_kabupaten_kota"] == "KABUPATEN BOGOR"]
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 27    28             32    JAWA BARAT                 3201
# 54    55             32    JAWA BARAT                 3201
# 81    82             32    JAWA BARAT                 3201
# 108  109             32    JAWA BARAT                 3201
# 135  136             32    JAWA BARAT                 3201
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 0       KABUPATEN BOGOR                57769  ORANG   2019
# 27      KABUPATEN BOGOR                71462  ORANG   2020
# 54      KABUPATEN BOGOR                61139  ORANG   2021
# 81      KABUPATEN BOGOR                63978  ORANG   2022
# 108     KABUPATEN BOGOR                65620  ORANG   2023
# 135     KABUPATEN BOGOR                65751  ORANG   2024

# %%
total_per_tahun = df.groupby("tahun")["jumlah_penderita_dm"].sum()
total_per_tahun
# Out:
# tahun
# 2019     848455
# 2020    1078857
# 2021     925675
# 2022     644704
# 2023     645390
# 2024     668220
# Name: jumlah_penderita_dm, dtype: int64

# %%
rata_per_kabupaten = df.groupby("nama_kabupaten_kota")["jumlah_penderita_dm"].mean()
rata_per_kabupaten
# Out:
# nama_kabupaten_kota
# KABUPATEN BANDUNG          51652.666667
# KABUPATEN BANDUNG BARAT    14246.333333
# KABUPATEN BEKASI           81174.333333
# KABUPATEN BOGOR            64286.500000
# KABUPATEN CIAMIS           38304.000000
# KABUPATEN CIANJUR          14363.166667
# KABUPATEN CIREBON          20553.333333
# KABUPATEN GARUT            20789.833333
# KABUPATEN INDRAMAYU        33056.666667
# KABUPATEN KARAWANG         92411.000000
# KABUPATEN KUNINGAN         21259.333333
# KABUPATEN MAJALENGKA       13028.333333
# KABUPATEN PANGANDARAN       7100.500000
# KABUPATEN PURWAKARTA       12953.500000
# KABUPATEN SUBANG           24120.166667
# KABUPATEN SUKABUMI         45277.500000
# KABUPATEN SUMEDANG         34894.000000
# KABUPATEN TASIKMALAYA      18176.333333
# KOTA BANDUNG               43480.166667
# KOTA BANJAR                 3610.666667
# KOTA BEKASI                45769.000000
# KOTA BOGOR                 17322.666667
# KOTA CIMAHI                 9817.166667
# ...

# %%
total_per_kab = df.groupby("nama_kabupaten_kota")["jumlah_penderita_dm"].sum()

kab_tertinggi = total_per_kab.idxmax()
nilai_tertinggi = total_per_kab.max()

kab_terendah = total_per_kab.idxmin()
nilai_terendah = total_per_kab.min()

kab_tertinggi, nilai_tertinggi, kab_terendah, nilai_terendah
# Out:
# ('KABUPATEN KARAWANG', np.int64(554466), 'KOTA BANJAR', np.int64(21664))
